# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Numerical data

# %% [markdown]
# # Line chart

# %%
df=pd.DataFrame({"Col01":np.random.random(100),"Col02":np.random.randn(100)})
df.head()
# Out:
#       Col01     Col02
# 0  0.238655  0.221928
# 1  0.278986  0.220992
# 2  0.446986 -0.584582
# 3  0.531017  0.462199
# 4  0.792020 -0.746674

# %%
#random.random use to 0-1 values
#random.randn use any values

# %%
df.plot.line(y="Col01",figsize=(8,7))
plt.xlabel("Col01")
plt.title("Col01 Line Chart")
plt.show()

# %% [markdown]
# # Histogram

# %%
df=pd.DataFrame({"Col01":np.random.random(100),"Col02":np.random.randn(100)})
df.head()
# Out:
#       Col01     Col02
# 0  0.094406  0.546938
# 1  0.659142 -0.298682
# 2  0.849988 -0.485334
# 3  0.848768  1.337025
# 4  0.199218  0.366383

# %%
df["Col01"].hist()
plt.xlabel("Col01")
plt.ylabel("Frequency")
plt.title("Col01 Histogram")
plt.show()

# %%
df["Col02"].hist()
plt.xlabel("Col02")
plt.ylabel("Frequency")
plt.title("Col02 Histogram")
plt.show()

# %% [markdown]
# # Boxplot

# %%
df=pd.DataFrame({"Col01":np.random.random(100),"Col02":np.random.random(100)})
df.head()
# Out:
#       Col01     Col02
# 0  0.567763  0.203110
# 1  0.292243  0.177749
# 2  0.911070  0.488861
# 3  0.736872  0.763824
# 4  0.072062  0.873349

# %%
df["Col01"].plot.box()
plt.title("Col01 Boxplot")
plt.show()

# %% [markdown]
# # Categorical data

# %% [markdown]
# # Bar graphs

# %%
data = {"City":["Kandy", "Colombo", "Galle"], "Visits":[50,45,70]}
df=pd.DataFrame(data)
df
# Out:
#       City  Visits
# 0    Kandy      50
# 1  Colombo      45
# 2    Galle      70

# %%
df.plot.bar(x="City", y="Visits")
plt.title("Tourist visits during last week")
plt.ylabel("Frequency")
plt.show()

# %%
df.plot.barh(x="City", y="Visits")
plt.title("Tourist visits during last week")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Pie charts

# %%
data = {"Visits":[50,45,70]}
df=pd.DataFrame(data,index=["Kandy", "Colombo", "Galle"])
df
# Out:
#          Visits
# Kandy        50
# Colombo      45
# Galle        70

# %%
df.plot.pie(y="Visits",figsize=(8,10))
plt.title("Tourist visits during last week")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Numerical VS Numerical data

# %% [markdown]
# # Scatter plots

# %%
df=pd.DataFrame({"Col01":np.random.random(100),"Col02":np.random.randn(100),"Col03":np.random.randn(100)})
df.head()
# Out:
#       Col01     Col02     Col03
# 0  0.129315  0.145448  0.133968
# 1  0.833054  1.202331  0.855799
# 2  0.883621 -0.369090 -0.407788
# 3  0.931194  0.200404  0.547468
# 4  0.690059  0.526999 -1.332179

# %%
df.plot.scatter(x="Col01", y="Col02")
plt.title("Col01 VS Col02")
plt.show()

# %% [markdown]
# # Categorical VS Categorical data

# %% [markdown]
# # Multiple bar graphs

# %%
df=pd.DataFrame({"Maths":[90,60],"Science":[78,83]},index=["Male","Female"])
df
# Out:
#         Maths  Science
# Male       90       78
# Female     60       83

# %%
df.plot.bar()
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %%
df.plot.barh()
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Stacked bar graphs

# %%
df.plot.bar(stacked=True)
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %%
df.plot.barh(stacked=True)
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # 100% Stacked bar graphs

# %%
df=pd.DataFrame({"Maths":[90,60],"Science":[78,83]},index=["Male","Female"])
df
# Out:
#         Maths  Science
# Male       90       78
# Female     60       83

# %%
df_perc=df.div(df.sum(axis=1),axis=0)*100
df_perc
# Out:
#             Maths    Science
# Male    53.571429  46.428571
# Female  41.958042  58.041958

# %%
df_perc.plot.bar(stacked=True)
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %%
df_perc.plot.barh(stacked=True)
plt.title("Maths & Science marks with gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Numerical VS Categorical data

# %% [markdown]
# # Side by side boxplots

# %%
data={"Cat":["A","A","A","A","A","B","B","B","B","B","C","C","C","C","C"],
     "Val":np.random.random(15)}
df=pd.DataFrame(data)
df
# Out:
#    Cat       Val
# 0    A  0.832725
# 1    A  0.328377
# 2    A  0.309523
# 3    A  0.161695
# 4    A  0.565886
# 5    B  0.910427
# 6    B  0.569153
# 7    B  0.937474
# 8    B  0.675844
# 9    B  0.251394
# 10   C  0.447973
# 11   C  0.265697
# 12   C  0.644806
# 13   C  0.776903
# 14   C  0.980375

# %%
df.boxplot("Val",by="Cat",figsize=(8,7))
plt.show()
