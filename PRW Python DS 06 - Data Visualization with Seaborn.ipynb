# %% [markdown]
# # Importing seaborn

# %%
import seaborn as sns
import pandas as pd #For future usage
import numpy as np  #For future usage
import matplotlib.pyplot as plt #For future usage

# %% [markdown]
# # Numerical data

# %% [markdown]
# # Line charts

# %%
x=np.arange(100)
y=np.random.normal(20,3,100)
sns.lineplot(x,y)
plt.title("Simple line chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=pd.DataFrame({"Year":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000],
                 "Weight":[76,64,65,70,78,79,75,74,69,68,65],
                "Height":[167,168,168,168,169,170,171,171,172,173,174]})
df
# Out:
#     Year  Weight  Height
# 0   1990      76     167
# 1   1991      64     168
# 2   1992      65     168
# 3   1993      70     168
# 4   1994      78     169
# 5   1995      79     170
# 6   1996      75     171
# 7   1997      74     171
# 8   1998      69     172
# 9   1999      68     173
# 10  2000      65     174

# %%
sns.lineplot(data=df,x="Year",y="Weight")
plt.title("Weight with years")
plt.xlabel("Year")
plt.ylabel("Weight")
plt.show()

# %%
sns.lineplot(data=df,x="Year",y="Weight")
sns.lineplot(data=df,x="Year",y="Height")
plt.title("Weight with years")
plt.xlabel("Year")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# # Histogram

# %%
age=np.random.randint(50,100,500)
sns.distplot(age)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
weight=np.random.normal(50,3,500)
sns.distplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Boxplot

# %%
weight=np.random.normal(50,3,500)
sns.boxplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Boxenplot

# %%
weight=np.random.normal(50,3,500)
sns.boxenplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxenplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Violin plot

# %%
weight=np.random.normal(50,3,500)
sns.violinplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
weight=np.random.normal(50,3,500)
sns.violinplot(weight,inner=None)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.violinplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Categorical data

# %% [markdown]
# # Bar graphs

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %% [markdown]
# # Vertical

# %%
sns.barplot(data=df,x="Gender",y="Number_of_Students")
plt.title("Counts for Gender")
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
g=titanic.groupby("sex")["sex"].count()
df=pd.DataFrame(g)
df.columns=["Count"]
df.reset_index(inplace=True)
df
# Out:
#       sex  Count
# 0  female    314
# 1    male    577

# %%
sns.barplot(data=df,x="sex",y="Count")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Horizontal

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %%
sns.barplot(data=df,y="Gender",x="Number_of_Students")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Counting the categories

# %%
df=pd.DataFrame({"Gender":["Male","Female","Male","Male","Female","Male"],"Age":[34,57,35,54,56,32]})
df
# Out:
#    Gender  Age
# 0    Male   34
# 1  Female   57
# 2    Male   35
# 3    Male   54
# 4  Female   56
# 5    Male   32

# %%
sns.countplot("Gender",data=df)
plt.title("Count for Gender")
plt.show()
# Out:
# C:\Users\Kodikara\User\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Pie chart is not available in seaborn library

# %% [markdown]
# # Bar plot using catplot

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %%
sns.catplot(data=df,x="Gender",y="Number_of_Students",kind="bar")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Categorical VS Numerical using catplot

# %% [markdown]
# # Categorical scatter plots

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int")})
df.head()
# Out:
#    Gender  Age
# 0    Male   35
# 1    Male   28
# 2  Female   27
# 3    Male   36
# 4  Female   38

# %%
sns.catplot(data=df,x="Gender",y="Age")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",jitter=False)
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",jitter=False,order=["Male","Female"])
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Swarm plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="swarm")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Represent another category

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int"),
                 "Class":np.random.choice(a=["A","B","C"],size=100)})
df.head()
# Out:
#    Gender  Age Class
# 0  Female   38     B
# 1  Female   38     B
# 2  Female   33     B
# 3    Male   30     C
# 4  Female   28     A

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="swarm",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %%
sns.swarmplot(data=df,x="Gender",y="Age",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Changing to horizontal

# %%
sns.catplot(data=df,y="Gender",x="Age",kind="swarm",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Side by side boxplots

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int"),
                 "Class":np.random.choice(a=["A","B","C"],size=100)})
df.head()
# Out:
#    Gender  Age Class
# 0    Male   31     C
# 1    Male   23     B
# 2    Male   31     A
# 3  Female   29     B
# 4    Male   27     C

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box",hue="Class",dodge=False)
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Side by side boxen plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="boxen")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Side by side violin plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="violin")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Swarm & violin plots together

# %%
g=sns.catplot(data=df,x="Gender",y="Age",kind="violin",inner=None)
sns.swarmplot(data=df,x="Gender",y="Age",ax=g.ax,color="black")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Bar graphs for averages with categorical data

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",kind="bar")
plt.title("Age with Gender")
plt.show()

# %% [markdown]
# # Comparing one numerical variable with two categorical variables

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",hue="alive",kind="bar")
plt.title("Age with Gender")
plt.show()

# %% [markdown]
# # Point charts for averages with categorical data

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",kind="point")
plt.title("Age with Gender")
plt.show()

# %%
sns.catplot(data=titanic,x="sex",y="age",hue="alive",kind="point")
plt.title("Age with Gender")
plt.show()

# %% [markdown]
# # Categorical VS Categorical data using catplot

# %% [markdown]
# # Multiple bar graphs

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x="sex", kind="count", hue="alive", data=titanic)
plt.title("Death status with Gender")
plt.show()

# %% [markdown]
# # Numerical VS Numerical data using catplot

# %% [markdown]
# # Scatter plots

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.title("Tips VS Total Bill")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex")
plt.title("Tips VS Total Bill")
plt.show()

# %% [markdown]
# # Bubble plots (Comparing 3 numerical variables)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill",  y="tip",size="size",hue="sex")
plt.title("Tips VS Total Bill")
plt.show()

# %% [markdown]
# # Pair plots

# %%
titanic = sns.load_dataset("titanic")
df=titanic[["age","fare"]]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
sns.pairplot(df)
plt.show()

# %%
df=pd.DataFrame({"val1":np.random.random(100),"val2":np.random.randn(100),"val3":np.random.normal(50,2,100)})
df.head()
# Out:
#        val1      val2       val3
# 0  0.935828  0.859392  47.684531
# 1  0.687357  0.606889  50.030656
# 2  0.192707 -0.708770  51.334052
# 3  0.524453  1.910608  49.206915
# 4  0.384187 -1.103161  48.871267

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Heat maps

# %%
df=pd.DataFrame({"Loc1":[0,10,20],"Loc2":[10,0,15],"Loc3":[20,15,0]},index=["Loc1","Loc2","Loc3"])
df
# Out:
#       Loc1  Loc2  Loc3
# Loc1     0    10    20
# Loc2    10     0    15
# Loc3    20    15     0

# %%
sns.heatmap(df,annot=True)  #annot show numbers
plt.show()

# %%
titanic = sns.load_dataset("titanic")
df=titanic[["age","fare"]]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df.corr()
# Out:
#            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1)
plt.show()

# %%
df1=pd.read_csv("D:\Python\default.CSV")
df1.head()
# Out:
#    Gender  Loan.Offered        Job  Work.Exp  Credit.Score  EMI.Ratio Status  \
# 0    Male             0  unskilled        14            86        3.0     No
# 1  Female             1    skilled        15            94        3.0     No
# 2    Male             0  unskilled        16            86        3.0     No
# 3  Female             1    skilled        13            94        3.0     No
# 4    Male             1    skilled        12            85        3.3     No
#
#   Credit.History  Own house   Purpose  Dependents
# 0           poor          1  personal           2
# 1           poor          1  personal           3
# 2           poor          1  personal           2
# 3           poor          1  personal           3
# 4           poor          1  personal           2

# %%
df1.corr()
# Out:
#               Loan.Offered  Work.Exp  Credit.Score  EMI.Ratio  Own house  \
# Loan.Offered      1.000000 -0.076224     -0.082435   0.057273  -0.085104
# Work.Exp         -0.076224  1.000000      0.915575  -0.300286   0.418791
# Credit.Score     -0.082435  0.915575      1.000000  -0.382192   0.497118
# EMI.Ratio         0.057273 -0.300286     -0.382192   1.000000  -0.221074
# Own house        -0.085104  0.418791      0.497118  -0.221074   1.000000
# Dependents       -0.029145  0.408753      0.490798  -0.251782   0.374587
#
#               Dependents
# Loan.Offered   -0.029145
# Work.Exp        0.408753
# Credit.Score    0.490798
# EMI.Ratio      -0.251782
# Own house       0.374587
# Dependents      1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr(),annot=True)  #annot show numbers
plt.show()
